# %%
from utils import *

# %%
from pathlib import Path

# %%
pwd
# Out:
# '/home/jupyter/tutorials/fastai/personal'

# %%
ls data/img2label_ds_v1/"Doing something"
# Out:
# 00065.png  00595.png  01130.png  01499.png  02016.png  02526.png  03264.png
# 00066.png  00599.png  01133.png  01514.png  02020.png  02540.png  03267.png
# 00076.png  00601.png  01134.png  01522.png  02021.png  02581.png  03279.png
# 00087.png  00610.png  01135.png  01523.png  02028.png  02582.png  03292.png
# 00090.png  00614.png  01138.png  01526.png  02029.png  02598.png  03297.png
# 00093.png  00615.png  01143.png  01535.png  02038.png  02602.png  03341.png
# 00102.png  00617.png  01172.png  01557.png  02042.png  02642.png  03364.png
# 00103.png  00638.png  01182.png  01566.png  02044.png  02644.png  03404.png
# 00110.png  00639.png  01187.png  01567.png  02045.png  02647.png  03413.png
# 00112.png  00646.png  01196.png  01575.png  02048.png  02660.png  03418.png
# 00124.png  00656.png  01197.png  01576.png  02049.png  02691.png  03436.png
# 00130.png  00657.png  01201.png  01586.png  02054.png  02714.png  03449.png
# ...

# %% [raw]
# !unzip -h

# %% [raw]
# !unzip -o data/img2label_ds_v1.zip -d data

# %%
img = PILImage.create('data/img2label_ds_v1/Doing something/00065.png')
img.to_thumb(300)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F2B2FDED510>

# %%
from fastai2.vision.all import *

# %%
path = Path('data/img2label_ds_v1')

# %%
bs = 64
# dls = ImageDataLoaders.from_folder(path, valid_pct=0.2, item_tfms=Resize(224), seed=42, bs=bs)
dls = ImageDataLoaders.from_folder(path, valid_pct=0.2, seed=42, bs=bs)

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate).to_fp16()
learn.fine_tune(100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.511230</td>
#       <td>1.722062</td>
#       <td>0.607973</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.833892</td>
#       <td>1.642224</td>
#       <td>0.578073</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.511428</td>
#       <td>1.576548</td>
#       <td>0.558140</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...

# %%
learn.recorder.plot_loss()

# %%
learn.recorder.plot_sched()

# %% [raw]
# learn.recorder.plot_lr_find()

# %%
learn.show_results()
