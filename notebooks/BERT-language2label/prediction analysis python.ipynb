# %%
import pandas as pd
from pathlib import Path

# %%
path = "/notebooks/language2motion.gt/data/labels_ds_v1_preds.csv"

# %%
pd = pd.read_csv(path)
pd.head()
# Out:
#    sample_id                                     text  \
# 0          1            A person is walking forwards.
# 1          2          A person walks 4 steps forward.
# 2          3                          A human walking
# 3          4  A person walks forward at medium speed.
# 4          5    A human walks four slow steps forward
#
#                        label                       pred      prob
# 0         Walking or running         Walking or running  0.960625
# 1  Walking forward few steps  Walking forward few steps  0.846991
# 2         Walking or running         Walking or running  0.948300
# 3         Walking or running         Walking or running  0.895835
# 4  Walking forward few steps         Walking or running  0.606713

# %%
walk_df = pd[pd.text.str.contains("walk")]
walk_df
# Out:
#       sample_id                                               text  \
# 0             1                      A person is walking forwards.
# 1             2                    A person walks 4 steps forward.
# 2             3                                    A human walking
# 3             4            A person walks forward at medium speed.
# 4             5              A human walks four slow steps forward
# ...         ...                                                ...
# 2952       3860                            A human walks upstairs.
# 2953       3861                           A human walks up stairs.
# 2954       3862  A person is walking around a corner by turning...
# 2955       3863                A human walks and takes a 90° turn.
# 2956       3865  A person walks straight forwards and then walk...
#
#                           label                       pred      prob
# 0            Walking or running         Walking or running  0.960625
# ...

# %%
walk_df.to_csv("/notebooks/language2motion.gt/data/labels_ds_v1_preds_walk.csv", index=False)
